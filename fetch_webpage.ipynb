# %%
working_list
log

# %%
import requests
from urllib.parse import quote

entry = "fallijan"
title = f"Reconstruction:Proto-West_Germanic/{entry}"
encoded_title = quote(title, safe=":/")

url = "https://en.wiktionary.org/w/api.php"
params = {
    "action": "query",
    "format": "json",
    "titles": encoded_title,
    "prop": "extracts",
    "explaintext": True
}
headers = {"User-Agent": "ProtoWordFetcher/1.0 (contact@example.com)"}

response = requests.get(url, params=params, headers=headers)

if response.status_code == 200:
    data = response.json()
    pages = data["query"]["pages"]
    for _, p in pages.items():
        print("Title:", p.get("title"))
        print("Exists:", "missing" not in p)
        print(p.get("extract", "")[:800])
else:
    print("HTTP Error:", response.status_code)
    print(response.text)
# Out:
# Title: Reconstruction:Proto-West Germanic/fallijan
# Exists: True
#
# == Proto-West Germanic ==
#
#
# === Etymology ===
# From Proto-Germanic *fallijaną.
#
#
# === Verb ===
# fallijan
#
# to cause to fall, to fell
#
#
# ==== Inflection ====
#
#
# ==== Related terms ====
# *fallan
#
#
# ==== Descendants ====
# Old English: fellan, fiellan
# Middle English: fellen
# Scots: fell
# English: fell
# Old Frisian: fella, falla
# West Frisian: falle
# Old Saxon: fellian
# Middle Low German: vellen
# Low German: fällen
# Old Dutch: *fellen
# Middle Dutch: vellen
# Dutch: vellen
# Afrikaans: vel
# Old High German: fellen
# Middle High German: vellen
# German: fällen
